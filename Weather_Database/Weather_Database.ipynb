# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates =list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []
# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
x = len(cities)
x
# Out:
# 756

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_clouds = city_weather["clouds"]["all"]
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_wind = city_weather["wind"]["speed"]
        city_current_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')    
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Cloudiness": city_clouds,
                          "Country": city_country,
                          "Date": city_date,
                          "Humidity": city_humidity,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Wind Speed": city_wind,
                          "Current Description":city_current_description})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | brewster
# Processing Record 2 of Set 1 | kruisfontein
# Processing Record 3 of Set 1 | hermanus
# Processing Record 4 of Set 1 | punta arenas
# Processing Record 5 of Set 1 | la paz
# Processing Record 6 of Set 1 | upernavik
# Processing Record 7 of Set 1 | aklavik
# Processing Record 8 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 9 of Set 1 | sisimiut
# Processing Record 10 of Set 1 | south venice
# Processing Record 11 of Set 1 | mataura
# Processing Record 12 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 13 of Set 1 | rikitea
# Processing Record 14 of Set 1 | chernyshevskiy
# Processing Record 15 of Set 1 | bargal
# City not found. Skipping...
# Processing Record 16 of Set 1 | khatanga
# Processing Record 17 of Set 1 | bowmore
# Processing Record 18 of Set 1 | hilo
# Processing Record 19 of Set 1 | tasiilaq
# Processing Record 20 of Set 1 | alice springs
# Processing Record 21 of Set 1 | yumen
# Processing Record 22 of Set 1 | port alfred
# Processing Record 23 of Set 1 | rio grande
# Processing Record 24 of Set 1 | bonham
# Processing Record 25 of Set 1 | albany
# Processing Record 26 of Set 1 | batesville
# Processing Record 27 of Set 1 | namikupa
# Processing Record 28 of Set 1 | busselton
# Processing Record 29 of Set 1 | bouafle
# Processing Record 30 of Set 1 | kodiak
# Processing Record 31 of Set 1 | ushuaia
# Processing Record 32 of Set 1 | nabire
# Processing Record 33 of Set 1 | tiksi
# Processing Record 34 of Set 1 | kabalo
# Processing Record 35 of Set 1 | dvinskoy
# Processing Record 36 of Set 1 | mumbwa
# Processing Record 37 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 38 of Set 1 | thompson
# Processing Record 39 of Set 1 | port hedland
# Processing Record 40 of Set 1 | provideniya
# Processing Record 41 of Set 1 | qaanaaq
# Processing Record 42 of Set 1 | palmer
# Processing Record 43 of Set 1 | navahrudak
# Processing Record 44 of Set 1 | norman wells
# Processing Record 45 of Set 1 | kapaa
# Processing Record 46 of Set 1 | tuktoyaktuk
# Processing Record 47 of Set 1 | hithadhoo
# Processing Record 48 of Set 1 | mar del plata
# Processing Record 49 of Set 1 | bluff
# Processing Record 50 of Set 1 | semme
# Processing Record 1 of Set 2 | kamenka
# Processing Record 2 of Set 2 | kaitangata
# Processing Record 3 of Set 2 | sovetskiy
# Processing Record 4 of Set 2 | talnakh
# Processing Record 5 of Set 2 | port elizabeth
# Processing Record 6 of Set 2 | narsaq
# Processing Record 7 of Set 2 | port augusta
# Processing Record 8 of Set 2 | sao filipe
# Processing Record 9 of Set 2 | mahebourg
# Processing Record 10 of Set 2 | puerto ayora
# Processing Record 11 of Set 2 | sabaudia
# Processing Record 12 of Set 2 | quimper
# Processing Record 13 of Set 2 | vao
# Processing Record 14 of Set 2 | jalu
# Processing Record 15 of Set 2 | east london
# Processing Record 16 of Set 2 | viligili
# City not found. Skipping...
# Processing Record 17 of Set 2 | severo-yeniseyskiy
# Processing Record 18 of Set 2 | soe
# Processing Record 19 of Set 2 | san patricio
# Processing Record 20 of Set 2 | dubti
# Processing Record 21 of Set 2 | jamestown
# Processing Record 22 of Set 2 | bambous virieux
# Processing Record 23 of Set 2 | brusyliv
# Processing Record 24 of Set 2 | amfiklia
# Processing Record 25 of Set 2 | codrington
# Processing Record 26 of Set 2 | omsukchan
# Processing Record 27 of Set 2 | beloha
# Processing Record 28 of Set 2 | torit
# Processing Record 29 of Set 2 | port lincoln
# Processing Record 30 of Set 2 | chokurdakh
# Processing Record 31 of Set 2 | arucas
# Processing Record 32 of Set 2 | atuona
# Processing Record 33 of Set 2 | vigrestad
# Processing Record 34 of Set 2 | redmond
# Processing Record 35 of Set 2 | georgiyevskoye
# Processing Record 36 of Set 2 | saint george
# Processing Record 37 of Set 2 | bozdar
# Processing Record 38 of Set 2 | panaba
# Processing Record 39 of Set 2 | vaini
# Processing Record 40 of Set 2 | ribeira grande
# Processing Record 41 of Set 2 | porto novo
# Processing Record 42 of Set 2 | cidreira
# Processing Record 43 of Set 2 | doha
# Processing Record 44 of Set 2 | tautira
# Processing Record 45 of Set 2 | bengkulu
# Processing Record 46 of Set 2 | gornyye klyuchi
# Processing Record 47 of Set 2 | cape town
# Processing Record 48 of Set 2 | markova
# Processing Record 49 of Set 2 | lethem
# Processing Record 50 of Set 2 | vardo
# Processing Record 1 of Set 3 | dikson
# Processing Record 2 of Set 3 | rawson
# Processing Record 3 of Set 3 | los llanos de aridane
# Processing Record 4 of Set 3 | chicama
# Processing Record 5 of Set 3 | estelle
# Processing Record 6 of Set 3 | vnorovy
# Processing Record 7 of Set 3 | gambela
# Processing Record 8 of Set 3 | lorengau
# Processing Record 9 of Set 3 | okha
# Processing Record 10 of Set 3 | emerald
# Processing Record 11 of Set 3 | belmonte
# Processing Record 12 of Set 3 | paamiut
# Processing Record 13 of Set 3 | high level
# Processing Record 14 of Set 3 | carnarvon
# Processing Record 15 of Set 3 | georgetown
# Processing Record 16 of Set 3 | seoul
# Processing Record 17 of Set 3 | bac lieu
# Processing Record 18 of Set 3 | avarua
# Processing Record 19 of Set 3 | kolchugino
# Processing Record 20 of Set 3 | ngukurr
# City not found. Skipping...
# Processing Record 21 of Set 3 | yulara
# Processing Record 22 of Set 3 | umzimvubu
# City not found. Skipping...
# Processing Record 23 of Set 3 | taft
# Processing Record 24 of Set 3 | sobolevo
# Processing Record 25 of Set 3 | honiara
# Processing Record 26 of Set 3 | saskylakh
# Processing Record 27 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 28 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 29 of Set 3 | puerto escondido
# Processing Record 30 of Set 3 | shubarkuduk
# Processing Record 31 of Set 3 | saint-philippe
# Processing Record 32 of Set 3 | shimoda
# Processing Record 33 of Set 3 | gornopravdinsk
# Processing Record 34 of Set 3 | duncanville
# Processing Record 35 of Set 3 | pangnirtung
# Processing Record 36 of Set 3 | bertoua
# Processing Record 37 of Set 3 | souillac
# Processing Record 38 of Set 3 | san miguel
# Processing Record 39 of Set 3 | tilichiki
# Processing Record 40 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 41 of Set 3 | zhanaozen
# Processing Record 42 of Set 3 | copiapo
# Processing Record 43 of Set 3 | nagaur
# Processing Record 44 of Set 3 | kaeo
# Processing Record 45 of Set 3 | hobart
# Processing Record 46 of Set 3 | castro
# Processing Record 47 of Set 3 | the valley
# Processing Record 48 of Set 3 | marica
# Processing Record 49 of Set 3 | chuy
# Processing Record 50 of Set 3 | zabol
# Processing Record 1 of Set 4 | yar-sale
# Processing Record 2 of Set 4 | mogadishu
# Processing Record 3 of Set 4 | geraldton
# Processing Record 4 of Set 4 | sindhnur
# Processing Record 5 of Set 4 | gwanda
# Processing Record 6 of Set 4 | erzin
# Processing Record 7 of Set 4 | kamina
# Processing Record 8 of Set 4 | denpasar
# Processing Record 9 of Set 4 | moose factory
# Processing Record 10 of Set 4 | gboko
# Processing Record 11 of Set 4 | iwanai
# Processing Record 12 of Set 4 | guerrero negro
# Processing Record 13 of Set 4 | lolua
# City not found. Skipping...
# Processing Record 14 of Set 4 | malakal
# Processing Record 15 of Set 4 | talaya
# Processing Record 16 of Set 4 | arcata
# Processing Record 17 of Set 4 | tripoli
# Processing Record 18 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 19 of Set 4 | hami
# Processing Record 20 of Set 4 | corinth
# Processing Record 21 of Set 4 | lebu
# Processing Record 22 of Set 4 | flinders
# Processing Record 23 of Set 4 | campo do brito
# Processing Record 24 of Set 4 | ponta delgada
# Processing Record 25 of Set 4 | huarmey
# Processing Record 26 of Set 4 | cabo san lucas
# Processing Record 27 of Set 4 | asau
# Processing Record 28 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 29 of Set 4 | manado
# Processing Record 30 of Set 4 | ponta do sol
# Processing Record 31 of Set 4 | butaritari
# Processing Record 32 of Set 4 | moerai
# Processing Record 33 of Set 4 | bredasdorp
# Processing Record 34 of Set 4 | camacha
# Processing Record 35 of Set 4 | atbasar
# Processing Record 36 of Set 4 | touros
# Processing Record 37 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 38 of Set 4 | oranjestad
# Processing Record 39 of Set 4 | laguna
# Processing Record 40 of Set 4 | marabba
# Processing Record 41 of Set 4 | qui nhon
# Processing Record 42 of Set 4 | hammerfest
# Processing Record 43 of Set 4 | torbay
# Processing Record 44 of Set 4 | te anau
# Processing Record 45 of Set 4 | port blair
# Processing Record 46 of Set 4 | gunnedah
# Processing Record 47 of Set 4 | westport
# Processing Record 48 of Set 4 | adrar
# Processing Record 49 of Set 4 | tidore
# City not found. Skipping...
# Processing Record 50 of Set 4 | yellowknife
# Processing Record 1 of Set 5 | barrow
# Processing Record 2 of Set 5 | manavalakurichi
# Processing Record 3 of Set 5 | alofi
# Processing Record 4 of Set 5 | odienne
# Processing Record 5 of Set 5 | cockburn town
# Processing Record 6 of Set 5 | pangkalanbuun
# Processing Record 7 of Set 5 | mizpe ramon
# City not found. Skipping...
# Processing Record 8 of Set 5 | klaksvik
# Processing Record 9 of Set 5 | iranshahr
# Processing Record 10 of Set 5 | sitka
# Processing Record 11 of Set 5 | falealupo
# City not found. Skipping...
# Processing Record 12 of Set 5 | solton
# Processing Record 13 of Set 5 | kuching
# Processing Record 14 of Set 5 | warqla
# City not found. Skipping...
# Processing Record 15 of Set 5 | mandan
# Processing Record 16 of Set 5 | wulanhaote
# City not found. Skipping...
# Processing Record 17 of Set 5 | new norfolk
# Processing Record 18 of Set 5 | bethel
# Processing Record 19 of Set 5 | toliary
# City not found. Skipping...
# Processing Record 20 of Set 5 | itarema
# Processing Record 21 of Set 5 | beisfjord
# Processing Record 22 of Set 5 | arraial do cabo
# Processing Record 23 of Set 5 | saint-pierre
# Processing Record 24 of Set 5 | namatanai
# Processing Record 25 of Set 5 | tomatlan
# Processing Record 26 of Set 5 | victoria
# Processing Record 27 of Set 5 | ulladulla
# Processing Record 28 of Set 5 | half moon bay
# Processing Record 29 of Set 5 | luderitz
# Processing Record 30 of Set 5 | lagos
# Processing Record 31 of Set 5 | ontario
# Processing Record 32 of Set 5 | plettenberg bay
# Processing Record 33 of Set 5 | banff
# Processing Record 34 of Set 5 | karmala
# Processing Record 35 of Set 5 | altamont
# Processing Record 36 of Set 5 | saldanha
# Processing Record 37 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 38 of Set 5 | cherskiy
# Processing Record 39 of Set 5 | nikolskoye
# Processing Record 40 of Set 5 | kitimat
# Processing Record 41 of Set 5 | saint-augustin
# Processing Record 42 of Set 5 | mount isa
# Processing Record 43 of Set 5 | lucea
# Processing Record 44 of Set 5 | olivehurst
# Processing Record 45 of Set 5 | betsiamites
# Processing Record 46 of Set 5 | marystown
# Processing Record 47 of Set 5 | haimen
# Processing Record 48 of Set 5 | tunghsiao
# City not found. Skipping...
# Processing Record 49 of Set 5 | airai
# Processing Record 50 of Set 5 | carmo do paranaiba
# Processing Record 1 of Set 6 | hasaki
# Processing Record 2 of Set 6 | esperance
# Processing Record 3 of Set 6 | camana
# Processing Record 4 of Set 6 | lavrentiya
# Processing Record 5 of Set 6 | eirunepe
# Processing Record 6 of Set 6 | itigi
# Processing Record 7 of Set 6 | isaka
# Processing Record 8 of Set 6 | cranbrook
# Processing Record 9 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 10 of Set 6 | grand gaube
# Processing Record 11 of Set 6 | constitucion
# Processing Record 12 of Set 6 | januaria
# Processing Record 13 of Set 6 | homer
# Processing Record 14 of Set 6 | ancud
# Processing Record 15 of Set 6 | eureka
# Processing Record 16 of Set 6 | vung tau
# Processing Record 17 of Set 6 | la palma
# Processing Record 18 of Set 6 | launceston
# Processing Record 19 of Set 6 | iqaluit
# Processing Record 20 of Set 6 | uvat
# Processing Record 21 of Set 6 | lompoc
# Processing Record 22 of Set 6 | kangavar
# Processing Record 23 of Set 6 | grand-lahou
# Processing Record 24 of Set 6 | lagoa
# Processing Record 25 of Set 6 | longyearbyen
# Processing Record 26 of Set 6 | pisco
# Processing Record 27 of Set 6 | sabang
# Processing Record 28 of Set 6 | neepawa
# Processing Record 29 of Set 6 | yerbogachen
# Processing Record 30 of Set 6 | kalanguy
# Processing Record 31 of Set 6 | liverpool
# Processing Record 32 of Set 6 | qasigiannguit
# Processing Record 33 of Set 6 | baruun-urt
# Processing Record 34 of Set 6 | hazro
# Processing Record 35 of Set 6 | ust-karsk
# Processing Record 36 of Set 6 | sorong
# Processing Record 37 of Set 6 | ejido
# Processing Record 38 of Set 6 | anton lizardo
# Processing Record 39 of Set 6 | shimanovsk
# Processing Record 40 of Set 6 | thinadhoo
# Processing Record 41 of Set 6 | bandarbeyla
# Processing Record 42 of Set 6 | oum hadjer
# Processing Record 43 of Set 6 | buzmeyin
# Processing Record 44 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 45 of Set 6 | felanitx
# Processing Record 46 of Set 6 | brae
# Processing Record 47 of Set 6 | lata
# Processing Record 48 of Set 6 | chipinge
# Processing Record 49 of Set 6 | raymond
# Processing Record 50 of Set 6 | faya
# Processing Record 1 of Set 7 | linfen
# Processing Record 2 of Set 7 | megion
# Processing Record 3 of Set 7 | murdochville
# Processing Record 4 of Set 7 | voskresenskoye
# Processing Record 5 of Set 7 | costa rica
# Processing Record 6 of Set 7 | sao felix do xingu
# Processing Record 7 of Set 7 | cockburn harbour
# City not found. Skipping...
# Processing Record 8 of Set 7 | goderich
# Processing Record 9 of Set 7 | saurimo
# Processing Record 10 of Set 7 | kalabo
# Processing Record 11 of Set 7 | clyde river
# Processing Record 12 of Set 7 | zhaoyuan
# Processing Record 13 of Set 7 | leshan
# Processing Record 14 of Set 7 | port-gentil
# Processing Record 15 of Set 7 | neuquen
# Processing Record 16 of Set 7 | arinos
# Processing Record 17 of Set 7 | zhigansk
# Processing Record 18 of Set 7 | bud
# Processing Record 19 of Set 7 | malwan
# City not found. Skipping...
# Processing Record 20 of Set 7 | lazaro cardenas
# Processing Record 21 of Set 7 | biak
# Processing Record 22 of Set 7 | karratha
# Processing Record 23 of Set 7 | sur
# Processing Record 24 of Set 7 | bathsheba
# Processing Record 25 of Set 7 | ambovombe
# Processing Record 26 of Set 7 | srednebelaya
# Processing Record 27 of Set 7 | srednekolymsk
# Processing Record 28 of Set 7 | severo-kurilsk
# Processing Record 29 of Set 7 | abiy adi
# City not found. Skipping...
# Processing Record 30 of Set 7 | moussoro
# Processing Record 31 of Set 7 | tavda
# Processing Record 32 of Set 7 | karak
# Processing Record 33 of Set 7 | hvide sande
# Processing Record 34 of Set 7 | fortuna
# Processing Record 35 of Set 7 | bolungarvik
# City not found. Skipping...
# Processing Record 36 of Set 7 | nova odesa
# Processing Record 37 of Set 7 | lyubech
# Processing Record 38 of Set 7 | callaway
# Processing Record 39 of Set 7 | tarakan
# Processing Record 40 of Set 7 | ariquemes
# Processing Record 41 of Set 7 | sedelnikovo
# City not found. Skipping...
# Processing Record 42 of Set 7 | mayo
# Processing Record 43 of Set 7 | najran
# Processing Record 44 of Set 7 | turochak
# Processing Record 45 of Set 7 | sao miguel do araguaia
# Processing Record 46 of Set 7 | lasa
# Processing Record 47 of Set 7 | hofn
# Processing Record 48 of Set 7 | vila franca do campo
# Processing Record 49 of Set 7 | rio de janeiro
# Processing Record 50 of Set 7 | husavik
# Processing Record 1 of Set 8 | rafaela
# Processing Record 2 of Set 8 | portland
# Processing Record 3 of Set 8 | shizunai
# Processing Record 4 of Set 8 | rapid valley
# Processing Record 5 of Set 8 | pierre
# Processing Record 6 of Set 8 | korla
# Processing Record 7 of Set 8 | faanui
# Processing Record 8 of Set 8 | ostrovnoy
# Processing Record 9 of Set 8 | meulaboh
# Processing Record 10 of Set 8 | satitoa
# City not found. Skipping...
# Processing Record 11 of Set 8 | chifeng
# Processing Record 12 of Set 8 | beringovskiy
# Processing Record 13 of Set 8 | aliwal north
# Processing Record 14 of Set 8 | coihaique
# Processing Record 15 of Set 8 | nicoya
# Processing Record 16 of Set 8 | chimbarongo
# Processing Record 17 of Set 8 | banyo
# Processing Record 18 of Set 8 | mehamn
# Processing Record 19 of Set 8 | sal rei
# Processing Record 20 of Set 8 | drexel heights
# Processing Record 21 of Set 8 | bowen
# Processing Record 22 of Set 8 | fare
# Processing Record 23 of Set 8 | pitimbu
# Processing Record 24 of Set 8 | martapura
# Processing Record 25 of Set 8 | houma
# Processing Record 26 of Set 8 | bograd
# Processing Record 27 of Set 8 | quatre cocos
# Processing Record 28 of Set 8 | northam
# Processing Record 29 of Set 8 | kavaratti
# Processing Record 30 of Set 8 | ginda
# Processing Record 31 of Set 8 | sukumo
# Processing Record 32 of Set 8 | tuggurt
# City not found. Skipping...
# Processing Record 33 of Set 8 | cayenne
# Processing Record 34 of Set 8 | luena
# Processing Record 35 of Set 8 | vaitupu
# City not found. Skipping...
# Processing Record 36 of Set 8 | itoman
# Processing Record 37 of Set 8 | marfino
# Processing Record 38 of Set 8 | canton
# Processing Record 39 of Set 8 | bantul
# Processing Record 40 of Set 8 | edd
# Processing Record 41 of Set 8 | taloqan
# Processing Record 42 of Set 8 | mackay
# Processing Record 43 of Set 8 | milos
# Processing Record 44 of Set 8 | vanimo
# Processing Record 45 of Set 8 | kavieng
# Processing Record 46 of Set 8 | guatire
# Processing Record 47 of Set 8 | mucurapo
# Processing Record 48 of Set 8 | manzil jamil
# City not found. Skipping...
# Processing Record 49 of Set 8 | acapulco
# Processing Record 50 of Set 8 | buritizeiro
# Processing Record 1 of Set 9 | mutis
# Processing Record 2 of Set 9 | ushtobe
# Processing Record 3 of Set 9 | pespire
# Processing Record 4 of Set 9 | fort nelson
# Processing Record 5 of Set 9 | talara
# Processing Record 6 of Set 9 | nioro
# Processing Record 7 of Set 9 | san carlos de bariloche
# Processing Record 8 of Set 9 | asfi
# Processing Record 9 of Set 9 | umm lajj
# Processing Record 10 of Set 9 | dunedin
# Processing Record 11 of Set 9 | kisangani
# Processing Record 12 of Set 9 | atherton
# Processing Record 13 of Set 9 | ngerengere
# Processing Record 14 of Set 9 | baraki barak
# Processing Record 15 of Set 9 | tupik
# Processing Record 16 of Set 9 | romanovskaya
# Processing Record 17 of Set 9 | kalininsk
# Processing Record 18 of Set 9 | presidencia roque saenz pena
# Processing Record 19 of Set 9 | coahuayana
# Processing Record 20 of Set 9 | karaul
# City not found. Skipping...
# Processing Record 21 of Set 9 | komsomolskiy
# Processing Record 22 of Set 9 | harper
# Processing Record 23 of Set 9 | mantua
# Processing Record 24 of Set 9 | san borja
# Processing Record 25 of Set 9 | dawson creek
# Processing Record 26 of Set 9 | krasnoselkup
# Processing Record 27 of Set 9 | fairbanks
# Processing Record 28 of Set 9 | san ignacio
# Processing Record 29 of Set 9 | nantucket
# Processing Record 30 of Set 9 | sambava
# Processing Record 31 of Set 9 | singkawang
# Processing Record 32 of Set 9 | shenkursk
# Processing Record 33 of Set 9 | prince rupert
# Processing Record 34 of Set 9 | camanducaia
# Processing Record 35 of Set 9 | moron
# Processing Record 36 of Set 9 | xique-xique
# Processing Record 37 of Set 9 | yeppoon
# Processing Record 38 of Set 9 | kungurtug
# Processing Record 39 of Set 9 | la baule-escoublac
# Processing Record 40 of Set 9 | itaituba
# Processing Record 41 of Set 9 | olinda
# Processing Record 42 of Set 9 | zverinogolovskoye
# Processing Record 43 of Set 9 | bubaque
# Processing Record 44 of Set 9 | gevrai
# Processing Record 45 of Set 9 | dataganj
# Processing Record 46 of Set 9 | soc trang
# Processing Record 47 of Set 9 | san cristobal
# Processing Record 48 of Set 9 | arman
# Processing Record 49 of Set 9 | beidao
# Processing Record 50 of Set 9 | svetlyy
# Processing Record 1 of Set 10 | sidi ali
# Processing Record 2 of Set 10 | hazleton
# Processing Record 3 of Set 10 | rocha
# Processing Record 4 of Set 10 | ndago
# Processing Record 5 of Set 10 | conde
# Processing Record 6 of Set 10 | manyana
# Processing Record 7 of Set 10 | sola
# Processing Record 8 of Set 10 | san felipe
# Processing Record 9 of Set 10 | meyungs
# City not found. Skipping...
# Processing Record 10 of Set 10 | tabuk
# Processing Record 11 of Set 10 | boa vista
# Processing Record 12 of Set 10 | phulabani
# Processing Record 13 of Set 10 | eyl
# Processing Record 14 of Set 10 | opuwo
# Processing Record 15 of Set 10 | bereda
# Processing Record 16 of Set 10 | birao
# Processing Record 17 of Set 10 | nizwa
# Processing Record 18 of Set 10 | kamenskoye
# City not found. Skipping...
# Processing Record 19 of Set 10 | cordoba
# Processing Record 20 of Set 10 | hervey bay
# Processing Record 21 of Set 10 | anadyr
# Processing Record 22 of Set 10 | zakamensk
# Processing Record 23 of Set 10 | dubbo
# Processing Record 24 of Set 10 | olafsvik
# Processing Record 25 of Set 10 | merauke
# Processing Record 26 of Set 10 | karamea
# City not found. Skipping...
# Processing Record 27 of Set 10 | banda aceh
# Processing Record 28 of Set 10 | dovolnoye
# Processing Record 29 of Set 10 | lixourion
# Processing Record 30 of Set 10 | ust-omchug
# Processing Record 31 of Set 10 | marcona
# City not found. Skipping...
# Processing Record 32 of Set 10 | vestmannaeyjar
# Processing Record 33 of Set 10 | caravelas
# Processing Record 34 of Set 10 | kushima
# Processing Record 35 of Set 10 | tuatapere
# Processing Record 36 of Set 10 | hit
# Processing Record 37 of Set 10 | kutum
# Processing Record 38 of Set 10 | poum
# Processing Record 39 of Set 10 | riyadh
# Processing Record 40 of Set 10 | bella vista
# Processing Record 41 of Set 10 | vaitape
# Processing Record 42 of Set 10 | shaunavon
# Processing Record 43 of Set 10 | teguise
# Processing Record 44 of Set 10 | conceicao do mato dentro
# Processing Record 45 of Set 10 | port hardy
# Processing Record 46 of Set 10 | bartica
# Processing Record 47 of Set 10 | el badari
# City not found. Skipping...
# Processing Record 48 of Set 10 | vila velha
# Processing Record 49 of Set 10 | khislavichi
# Processing Record 50 of Set 10 | ust-barguzin
# Processing Record 1 of Set 11 | erdenet
# Processing Record 2 of Set 11 | tecolutla
# Processing Record 3 of Set 11 | iralaya
# Processing Record 4 of Set 11 | berlevag
# Processing Record 5 of Set 11 | amahai
# Processing Record 6 of Set 11 | sinop
# Processing Record 7 of Set 11 | pfarrkirchen
# Processing Record 8 of Set 11 | pevek
# Processing Record 9 of Set 11 | tatawin
# Processing Record 10 of Set 11 | gat
# Processing Record 11 of Set 11 | bolshiye chapurniki
# City not found. Skipping...
# Processing Record 12 of Set 11 | palu
# Processing Record 13 of Set 11 | axim
# Processing Record 14 of Set 11 | zhezkazgan
# Processing Record 15 of Set 11 | pudozh
# Processing Record 16 of Set 11 | lamu
# Processing Record 17 of Set 11 | hearst
# Processing Record 18 of Set 11 | broome
# Processing Record 19 of Set 11 | gorontalo
# Processing Record 20 of Set 11 | aripuana
# Processing Record 21 of Set 11 | moyo
# Processing Record 22 of Set 11 | lexington
# Processing Record 23 of Set 11 | attawapiskat
# City not found. Skipping...
# Processing Record 24 of Set 11 | farafangana
# Processing Record 25 of Set 11 | moyale
# Processing Record 26 of Set 11 | shymkent
# Processing Record 27 of Set 11 | pasni
# Processing Record 28 of Set 11 | toumodi
# Processing Record 29 of Set 11 | turukhansk
# Processing Record 30 of Set 11 | ternate
# Processing Record 31 of Set 11 | rio claro
# Processing Record 32 of Set 11 | gainesville
# Processing Record 33 of Set 11 | burica
# City not found. Skipping...
# Processing Record 34 of Set 11 | raga
# Processing Record 35 of Set 11 | chapeco
# Processing Record 36 of Set 11 | inuvik
# Processing Record 37 of Set 11 | sapa
# Processing Record 38 of Set 11 | viedma
# Processing Record 39 of Set 11 | ilulissat
# Processing Record 40 of Set 11 | namibe
# Processing Record 41 of Set 11 | les cayes
# Processing Record 42 of Set 11 | port hawkesbury
# Processing Record 43 of Set 11 | liwale
# Processing Record 44 of Set 11 | pacific grove
# Processing Record 45 of Set 11 | san ramon
# Processing Record 46 of Set 11 | roma
# Processing Record 47 of Set 11 | gushikawa
# Processing Record 48 of Set 11 | shatrovo
# Processing Record 49 of Set 11 | panama city
# Processing Record 50 of Set 11 | lensk
# Processing Record 1 of Set 12 | arlit
# Processing Record 2 of Set 12 | mount gambier
# Processing Record 3 of Set 12 | deputatskiy
# Processing Record 4 of Set 12 | grindavik
# Processing Record 5 of Set 12 | do gonbadan
# Processing Record 6 of Set 12 | black river
# Processing Record 7 of Set 12 | sainte-suzanne
# Processing Record 8 of Set 12 | bucerias
# Processing Record 9 of Set 12 | monywa
# Processing Record 10 of Set 12 | sangmelima
# Processing Record 11 of Set 12 | waw
# Processing Record 12 of Set 12 | labuhan
# Processing Record 13 of Set 12 | solnechnyy
# Processing Record 14 of Set 12 | lincoln
# Processing Record 15 of Set 12 | salalah
# Processing Record 16 of Set 12 | avera
# Processing Record 17 of Set 12 | middelkerke
# Processing Record 18 of Set 12 | ondjiva
# Processing Record 19 of Set 12 | hovd
# Processing Record 20 of Set 12 | borogontsy
# Processing Record 21 of Set 12 | san rafael
# Processing Record 22 of Set 12 | henties bay
# Processing Record 23 of Set 12 | melioratorov
# Processing Record 24 of Set 12 | newport
# Processing Record 25 of Set 12 | qiongshan
# Processing Record 26 of Set 12 | burns lake
# Processing Record 27 of Set 12 | soyo
# Processing Record 28 of Set 12 | praia
# Processing Record 29 of Set 12 | penalva
# Processing Record 30 of Set 12 | gari
# Processing Record 31 of Set 12 | okahandja
# Processing Record 32 of Set 12 | buraydah
# Processing Record 33 of Set 12 | sao joao da barra
# Processing Record 34 of Set 12 | gigmoto
# Processing Record 35 of Set 12 | mineiros
# Processing Record 36 of Set 12 | los andes
# Processing Record 37 of Set 12 | vostok
# Processing Record 38 of Set 12 | pervomayskoye
# Processing Record 39 of Set 12 | amuntai
# Processing Record 40 of Set 12 | brufut
# Processing Record 41 of Set 12 | kedrovyy
# Processing Record 42 of Set 12 | dabakala
# Processing Record 43 of Set 12 | nueve de julio
# Processing Record 44 of Set 12 | gorodets
# Processing Record 45 of Set 12 | amot
# Processing Record 46 of Set 12 | kaseda
# Processing Record 47 of Set 12 | staryy nadym
# Processing Record 48 of Set 12 | lander
# Processing Record 49 of Set 12 | punta alta
# Processing Record 50 of Set 12 | nelson bay
# Processing Record 1 of Set 13 | afmadu
# City not found. Skipping...
# Processing Record 2 of Set 13 | artyk
# City not found. Skipping...
# Processing Record 3 of Set 13 | college
# Processing Record 4 of Set 13 | tigil
# Processing Record 5 of Set 13 | santiago de cao
# Processing Record 6 of Set 13 | katangli
# Processing Record 7 of Set 13 | talikota
# Processing Record 8 of Set 13 | yazoo city
# Processing Record 9 of Set 13 | paducah
# Processing Record 10 of Set 13 | wajima
# Processing Record 11 of Set 13 | mbala
# Processing Record 12 of Set 13 | tshela
# Processing Record 13 of Set 13 | santa rosa
# Processing Record 14 of Set 13 | sorrento
# Processing Record 15 of Set 13 | mildura
# Processing Record 16 of Set 13 | casper
# Processing Record 17 of Set 13 | krasne
# Processing Record 18 of Set 13 | isangel
# Processing Record 19 of Set 13 | porbandar
# Processing Record 20 of Set 13 | nishihara
# Processing Record 21 of Set 13 | charlestown
# Processing Record 22 of Set 13 | umm kaddadah
# Processing Record 23 of Set 13 | changli
# Processing Record 24 of Set 13 | sorvag
# City not found. Skipping...
# Processing Record 25 of Set 13 | tianpeng
# Processing Record 26 of Set 13 | vohibinany
# Processing Record 27 of Set 13 | katsuura
# Processing Record 28 of Set 13 | malinovoye ozero
# Processing Record 29 of Set 13 | bairiki
# Processing Record 30 of Set 13 | havre-saint-pierre
# Processing Record 31 of Set 13 | sampit
# Processing Record 32 of Set 13 | willowmore
# Processing Record 33 of Set 13 | klyuchi
# Processing Record 34 of Set 13 | caruray
# Processing Record 35 of Set 13 | comodoro rivadavia
# Processing Record 36 of Set 13 | makakilo city
# Processing Record 37 of Set 13 | yuryevets
# Processing Record 38 of Set 13 | mareeba
# Processing Record 39 of Set 13 | zonguldak
# Processing Record 40 of Set 13 | sale
# Processing Record 41 of Set 13 | muros
# Processing Record 42 of Set 13 | manaure
# Processing Record 43 of Set 13 | eenhana
# Processing Record 44 of Set 13 | coquimbo
# Processing Record 45 of Set 13 | nanortalik
# Processing Record 46 of Set 13 | waraseoni
# Processing Record 47 of Set 13 | na wa
# Processing Record 48 of Set 13 | garmsar
# Processing Record 49 of Set 13 | port jervis
# Processing Record 50 of Set 13 | kurri kurri
# Processing Record 1 of Set 14 | chulman
# Processing Record 2 of Set 14 | jardim
# Processing Record 3 of Set 14 | constantine
# Processing Record 4 of Set 14 | marhaura
# Processing Record 5 of Set 14 | cristobal obregon
# Processing Record 6 of Set 14 | marrakesh
# Processing Record 7 of Set 14 | khandyga
# Processing Record 8 of Set 14 | tarudant
# City not found. Skipping...
# Processing Record 9 of Set 14 | dutse
# Processing Record 10 of Set 14 | sirsilla
# Processing Record 11 of Set 14 | moree
# Processing Record 12 of Set 14 | aranda de duero
# Processing Record 13 of Set 14 | sakaiminato
# Processing Record 14 of Set 14 | lisakovsk
# Processing Record 15 of Set 14 | kazanskoye
# Processing Record 16 of Set 14 | aswan
# Processing Record 17 of Set 14 | atambua
# Processing Record 18 of Set 14 | marzuq
# Processing Record 19 of Set 14 | houston
# Processing Record 20 of Set 14 | harrisonville
# Processing Record 21 of Set 14 | skibbereen
# Processing Record 22 of Set 14 | milledgeville
# Processing Record 23 of Set 14 | majene
# Processing Record 24 of Set 14 | chiang rai
# Processing Record 25 of Set 14 | nalut
# Processing Record 26 of Set 14 | naze
# Processing Record 27 of Set 14 | podor
# Processing Record 28 of Set 14 | yunyang
# Processing Record 29 of Set 14 | chambersburg
# Processing Record 30 of Set 14 | nyurba
# Processing Record 31 of Set 14 | tutoia
# Processing Record 32 of Set 14 | palafrugell
# Processing Record 33 of Set 14 | donghai
# Processing Record 34 of Set 14 | evensk
# Processing Record 35 of Set 14 | saveh
# Processing Record 36 of Set 14 | owando
# Processing Record 37 of Set 14 | havelock
# Processing Record 38 of Set 14 | ozernovskiy
# Processing Record 39 of Set 14 | baculin
# Processing Record 40 of Set 14 | kahului
# Processing Record 41 of Set 14 | garowe
# Processing Record 42 of Set 14 | xining
# Processing Record 43 of Set 14 | beaverlodge
# Processing Record 44 of Set 14 | kamphaeng phet
# Processing Record 45 of Set 14 | priladozhskiy
# Processing Record 46 of Set 14 | dhidhdhoo
# Processing Record 47 of Set 14 | roebourne
# Processing Record 48 of Set 14 | srandakan
# Processing Record 49 of Set 14 | upata
# Processing Record 50 of Set 14 | kuito
# Processing Record 1 of Set 15 | orange
# Processing Record 2 of Set 15 | puerto baquerizo moreno
# Processing Record 3 of Set 15 | sfantu gheorghe
# Processing Record 4 of Set 15 | brisbane
# Processing Record 5 of Set 15 | cedral
# Processing Record 6 of Set 15 | ambodifototra
# City not found. Skipping...
# Processing Record 7 of Set 15 | sangar
# Processing Record 8 of Set 15 | dingle
# Processing Record 9 of Set 15 | saleaula
# City not found. Skipping...
# Processing Record 10 of Set 15 | sistranda
# Processing Record 11 of Set 15 | maun
# Processing Record 12 of Set 15 | araure
# Processing Record 13 of Set 15 | strezhevoy
# Processing Record 14 of Set 15 | kuzino
# Processing Record 15 of Set 15 | lebork
# Processing Record 16 of Set 15 | auki
# Processing Record 17 of Set 15 | khorinsk
# Processing Record 18 of Set 15 | padang
# Processing Record 19 of Set 15 | aldan
# Processing Record 20 of Set 15 | aykhal
# Processing Record 21 of Set 15 | sredec
# City not found. Skipping...
# Processing Record 22 of Set 15 | haapu
# City not found. Skipping...
# Processing Record 23 of Set 15 | slyudyanka
# Processing Record 24 of Set 15 | talcahuano
# Processing Record 25 of Set 15 | north bend
# Processing Record 26 of Set 15 | raudeberg
# Processing Record 27 of Set 15 | ust-kuyga
# Processing Record 28 of Set 15 | manokwari
# Processing Record 29 of Set 15 | chilca
# Processing Record 30 of Set 15 | sassandra
# Processing Record 31 of Set 15 | ambon
# Processing Record 32 of Set 15 | arrecife
# Processing Record 33 of Set 15 | barawe
# City not found. Skipping...
# Processing Record 34 of Set 15 | sorland
# Processing Record 35 of Set 15 | vila
# Processing Record 36 of Set 15 | okhotsk
# Processing Record 37 of Set 15 | buala
# Processing Record 38 of Set 15 | salta
# Processing Record 39 of Set 15 | maloshuyka
# City not found. Skipping...
# Processing Record 40 of Set 15 | el tigre
# Processing Record 41 of Set 15 | amazar
# Processing Record 42 of Set 15 | carutapera
# Processing Record 43 of Set 15 | vega de alatorre
# Processing Record 44 of Set 15 | skelleftea
# Processing Record 45 of Set 15 | dwarka
# Processing Record 46 of Set 15 | lumberton
# Processing Record 47 of Set 15 | glendive
# Processing Record 48 of Set 15 | eastbourne
# Processing Record 49 of Set 15 | kirensk
# Processing Record 50 of Set 15 | slavgorodskoye
# Processing Record 1 of Set 16 | kargasok
# Processing Record 2 of Set 16 | dosso
# Processing Record 3 of Set 16 | maler kotla
# Processing Record 4 of Set 16 | susanville
# Processing Record 5 of Set 16 | paita
# Processing Record 6 of Set 16 | kununurra
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 704

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#            City  Cloudiness Country                 Date  Humidity      Lat  \
# 0      Brewster         100      US  2022-11-12 05:11:06        93  41.3973
# 1  Kruisfontein           0      ZA  2022-11-12 05:11:07        63 -34.0033
# 2      Hermanus           0      ZA  2022-11-12 05:11:07        73 -34.4187
# 3  Punta Arenas           0      CL  2022-11-12 05:11:07        80 -53.1500
# 4        La Paz          18      BO  2022-11-12 05:08:48        30 -16.5000
# 5     Upernavik          96      GL  2022-11-12 05:11:08        79  72.7868
# 6       Aklavik          40      CA  2022-11-12 05:11:08        95  68.2191
# 7      Sisimiut          81      GL  2022-11-12 05:11:09        88  66.9395
# 8  South Venice          42      US  2022-11-12 05:11:09        97  27.0531
# 9       Mataura         100      NZ  2022-11-12 05:11:09        43 -46.1927
#
#         Lng  Max Temp  Wind Speed Current Description
# 0  -73.6171     71.01       13.80     overcast clouds
# 1   24.7314     72.23        2.06           clear sky
# 2   19.2345     60.80        7.67           clear sky
# 3  -70.9167     33.91        2.30           clear sky
# 4  -68.1500     42.78        2.30          few clouds
# 5  -56.1549     11.07        8.39     overcast clouds
# 6 -135.0107      4.33        8.03    scattered clouds
# 7  -53.6735     12.90        8.95       broken clouds
# 8  -82.4243     74.98        4.21    scattered clouds
# 9  168.8643     58.48        6.04     overcast clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Cloudiness', 'Country', 'Date', 'Humidity', 'Lat', 'Lng',
#        'Max Temp', 'Wind Speed', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
# Recreate the DataFrame by using the new column order

new_city_data_df = city_data_df[["City","Country","Lat","Lng","Max Temp","Humidity", "Cloudiness",
                                 "Wind Speed","Current Description"]].copy()

# Display sample data
new_city_data_df
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Brewster      US  41.3973  -73.6171     71.01        93         100
# 1    Kruisfontein      ZA -34.0033   24.7314     72.23        63           0
# 2        Hermanus      ZA -34.4187   19.2345     60.80        73           0
# 3    Punta Arenas      CL -53.1500  -70.9167     33.91        80           0
# 4          La Paz      BO -16.5000  -68.1500     42.78        30          18
# ..            ...     ...      ...       ...       ...       ...         ...
# 699         Dosso      NE  13.0490    3.1937     77.07        28          23
# 700   Maler Kotla      IN  30.5167   75.8833     75.06        26           0
# 701    Susanville      US  40.4163 -120.6530     28.81        91           0
# 702         Paita      PE  -5.0892  -81.1144     61.63        90          93
# 703     Kununurra      AU -15.7667  128.7333    102.18        32          40
#
#      Wind Speed Current Description
# 0         13.80     overcast clouds
# 1          2.06           clear sky
# 2          7.67           clear sky
# 3          2.30           clear sky
# 4          2.30          few clouds
# ..          ...                 ...
# 699       10.27          few clouds
# 700        7.54           clear sky
# 701        1.01           clear sky
# 702        7.31     overcast clouds
# 703        8.05    scattered clouds
#
# [704 rows x 9 columns]

# %%
# Display the data types of each column by using the dtypes Pandas function
new_city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "Weather_Database/WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
